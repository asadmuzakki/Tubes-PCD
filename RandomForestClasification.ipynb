# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv('glcm_result.csv')
data.head(6)
# Out:
#                                      path  contrast_0  dissimilarity_0  \
# 0  jenis_tanah/kurang subur\pasir-001.jpg  404.685999        14.964706
# 1  jenis_tanah/kurang subur\pasir-002.jpg  397.737684        14.697243
# 2  jenis_tanah/kurang subur\pasir-003.jpg  553.719792        17.670833
# 3  jenis_tanah/kurang subur\pasir-004.jpg  366.786091        13.968903
# 4  jenis_tanah/kurang subur\pasir-005.jpg  357.034620        14.044577
# 5  jenis_tanah/kurang subur\pasir-006.jpg  383.759298        14.451670
#
#    homogeneity_0  energy_0  correlation_0     entropy_0         asm_0  \
# 0       0.159150  0.000344       0.792057 -5.511811e+07  5.244877e-09
# 1       0.160085  0.000382       0.768577 -5.831939e+07  5.822941e-09
# 2       0.139289  0.000317       0.724201 -5.489267e+07  4.833738e-09
# 3       0.170994  0.000426       0.803619 -5.867574e+07  6.499706e-09
# 4       0.162988  0.000354       0.772160 -5.913406e+07  5.398336e-09
# 5       0.164500  0.000454       0.769084 -5.830542e+07  6.934796e-09
#
#    contrast_45  dissimilarity_45  ...    entropy_95        asm_90  \
# 0   583.984806         18.021407  ... -5.511811e+07  5.421791e-09
# 1   529.149158         16.981930  ... -5.831939e+07  6.359768e-09
# 2   786.174979         21.217193  ... -5.489267e+07  4.983489e-09
# 3   529.102222         16.814548  ... -5.867574e+07  6.763840e-09
# 4   530.439047         17.235879  ... -5.913406e+07  5.512932e-09
# 5   565.758493         17.636140  ... -5.830542e+07  7.150561e-09
#
#    contrast_135  dissimilarity_135  homogeneity_135  energy_135  \
# 0    756.250242          20.796217         0.120498    0.000259
# 1    680.839831          19.469896         0.127535    0.000300
# 2    960.578208          23.678677         0.108329    0.000251
# 3    659.481030          19.066667         0.133286    0.000322
# 4    630.332395          19.026282         0.126474    0.000273
# 5    668.120907          19.450427         0.127400    0.000351
#
#    correlation_135   entropy_135       asm_135        labels
# 0         0.610999 -5.511811e+07  3.956382e-09  kurang subur
# 1         0.603334 -5.831939e+07  4.580550e-09  kurang subur
# 2         0.521119 -5.489267e+07  3.827865e-09  kurang subur
# 3         0.646799 -5.867574e+07  4.916895e-09  kurang subur
# 4         0.597663 -5.913406e+07  4.166003e-09  kurang subur
# 5         0.597327 -5.830542e+07  5.356553e-09  kurang subur
#
# [6 rows x 30 columns]

# %%
y = data['labels']
x = data.drop(['path', 'labels'], axis=1)

# %%
data.isnull().any()
# Out:
# path                 False
# contrast_0           False
# dissimilarity_0      False
# homogeneity_0        False
# energy_0             False
# correlation_0        False
# entropy_0            False
# asm_0                False
# contrast_45          False
# dissimilarity_45     False
# homogeneity_45       False
# energy_45            False
# correlation_45       False
# entropy_45           False
# asm_45               False
# contrast_90          False
# dissimilarity_90     False
# homogeneity_90       False
# energy_90            False
# correlation_90       False
# entropy_95           False
# asm_90               False
# contrast_135         False
# dissimilarity_135    False
# homogeneity_135      False
# energy_135           False
# correlation_135      False
# entropy_135          False
# asm_135              False
# labels               False
# dtype: bool

# %%
data = data.fillna(0)
data.isnull().any()
# Out:
# path                 False
# contrast_0           False
# dissimilarity_0      False
# homogeneity_0        False
# energy_0             False
# correlation_0        False
# entropy_0            False
# asm_0                False
# contrast_45          False
# dissimilarity_45     False
# homogeneity_45       False
# energy_45            False
# correlation_45       False
# entropy_45           False
# asm_45               False
# contrast_90          False
# dissimilarity_90     False
# homogeneity_90       False
# energy_90            False
# correlation_90       False
# entropy_95           False
# asm_90               False
# contrast_135         False
# dissimilarity_135    False
# homogeneity_135      False
# energy_135           False
# correlation_135      False
# entropy_135          False
# asm_135              False
# labels               False
# dtype: bool

# %%
rf_model = RandomForestClassifier()
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf_model.fit(X_train, y_train)
rf_pred= rf_model.predict(X_test)

# %%
rf_accuracy = accuracy_score(y_test, rf_pred)
rf_report = classification_report(y_test, rf_pred)

# %%
print("Random Forest Accuracy:", rf_accuracy * 100, "%")
print("Random Forest Classification Report:\n", rf_report)
# Out:
# Random Forest Accuracy: 96.96969696969697 %
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
# kurang subur       0.95      0.95      0.95        22
#        subur       1.00      0.95      0.98        21
#  tidak subur       0.96      1.00      0.98        23
#
#     accuracy                           0.97        66
#    macro avg       0.97      0.97      0.97        66
# weighted avg       0.97      0.97      0.97        66
